# %%
import pandas as pd

crime_data = pd.read_json("https://data.cityofchicago.org/resource/dfnk-7re6.json")

# %%
crime_data.head(100)
# Out:
#     :@computed_region_43wa_7qmu  :@computed_region_6mkv_f3dw  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
# 5                           NaN                          NaN
# 6                           NaN                          NaN
# 7                           NaN                          NaN
# 8                           NaN                          NaN
# 9                           NaN                          NaN
# 10                          NaN                          NaN
# 11                          NaN                          NaN
# 12                          NaN                          NaN
# 13                          NaN                          NaN
# ...

# %%
len(crime_data)
# Out:
# 1000

# %%
crash_data = pd.read_json("https://data.cityofchicago.org/resource/85ca-t3if.json")

# %%
crash_data.head(10)
# Out:
#             alignment  beat_of_occurrence               crash_date  \
# 0  STRAIGHT AND LEVEL                1631  2019-08-28T02:13:00.000
# 1  STRAIGHT AND LEVEL                2432  2019-08-28T01:20:00.000
# 2  STRAIGHT AND LEVEL                1131  2019-08-28T00:30:00.000
# 3  STRAIGHT AND LEVEL                 321  2019-08-28T00:30:00.000
# 4  STRAIGHT AND LEVEL                 421  2019-08-28T00:04:00.000
# 5  STRAIGHT AND LEVEL                1222  2019-08-27T23:37:00.000
# 6  STRAIGHT AND LEVEL                 813  2019-08-27T23:30:00.000
# 7  STRAIGHT AND LEVEL                 421  2019-08-27T23:18:00.000
# 8  STRAIGHT AND LEVEL                1931  2019-08-27T22:30:00.000
# 9  STRAIGHT AND LEVEL                1431  2019-08-27T22:30:00.000
#
#   crash_date_est_i  crash_day_of_week  crash_hour  crash_month  \
# 0              NaN                  4           2            8
# 1              NaN                  4           1            8
# ...
